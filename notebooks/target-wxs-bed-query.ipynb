# %%
import requests
import json
import pandas as pd

# %%
gdc_url = 'https://api.gdc.cancer.gov/files'
headers = {'Content-Type': 'application/json'}

fields = [
    'file_id',
    'file_name',
    'data_category',
    'data_type',
    'experimental_strategy',
    'cases.submitter_id',
    'cases.samples.submitter_id',
    'cases.samples.sample_type',
    'cases.samples.portions.analytes.aliquots.submitter_id',
    'analysis.workflow_type',
    'analysis.metadata.read_groups.read_group_id',
    'analysis.metadata.read_groups.target_capture_kit_name',
    'analysis.metadata.read_groups.target_capture_kit_target_region'
]
fields = ','.join(fields)

manifest = pd.read_csv("/Users/zhuy/Downloads/gdc_manifest.2021-06-28-1.txt", sep='\t')

# %%
payload = {
        'filters':{
            'op':'=',
            'content':{
                'field':'file_id',
                'value':manifest.id.tolist()
            }
        },
        'format':'json',
        'fields':fields,
        'size':5000 # make sure we get all the returns
}
payload = json.dumps(payload)
gdc_response = requests.post(gdc_url, headers=headers, data=payload)
gdc_response = gdc_response.json()

# %%
lib_info = []
for i in gdc_response['data']['hits']:
    case = i['cases'][0]
    sample = case['samples'][0]
    aliquot = sample['portions'][0]['analytes'][0]['aliquots'][0]
    try:
        analysis = i['analysis']
    except:
        analysis = {
            'workflow_type':'null',
            'metadata':{
                'read_groups':[{
                    'target_capture_kit_name':'null',
                    'target_capture_kit_target_region':'null',
                    'read_group_id':'null'
                }]
            }
        }
    read_groups = analysis['metadata']['read_groups']
    for j in read_groups:
        lib_info.append([
            i['file_id'], i['file_name'], i['experimental_strategy'],
            i['data_type'], i['data_category'],
            case['submitter_id'],
            sample['submitter_id'], sample['sample_type'],
            aliquot['submitter_id'],
            analysis['workflow_type'],
            j['read_group_id'],
            j['target_capture_kit_name'],
            j['target_capture_kit_target_region']
        ])

# %%
df = pd.DataFrame(lib_info).drop_duplicates()
df.columns = [
    'file_id',
    'file_name',
    'experimental_strategy',
    'data_type',
    'data_category',
    'case_id',
    'sample_id',
    'sample_type',
    'aliquot_id',
    'workflow_type',
    'read_group_id',
    'target_capture_kit_name',
    'target_capture_kit_target_region'
]
df
# Out:
#                                     file_id  \
# 0      88ae30af-4e26-4ebb-9fdf-c6bf465bed5b
# 1      88ae30af-4e26-4ebb-9fdf-c6bf465bed5b
# 2      57e0e578-3bf9-4859-b821-a75cec5ee0da
# 3      b456d94f-9b65-4df9-b641-d889d0b0e273
# 4      1292f8ac-24ce-4f94-8fe9-e3da52e5ae49
# ...                                     ...
# 10675  77435788-f3c6-4059-a14f-001e949ddd57
# 10676  77435788-f3c6-4059-a14f-001e949ddd57
# 10677  77435788-f3c6-4059-a14f-001e949ddd57
# 10678  77435788-f3c6-4059-a14f-001e949ddd57
# 10679  d616c52d-b448-4f8b-85b6-189e0efde2aa
#
#                                                file_name  \
# 0      fc64f2ec-270a-4d0d-b976-aba7d5afa357_wxs_gdc_r...
# 1      fc64f2ec-270a-4d0d-b976-aba7d5afa357_wxs_gdc_r...
# 2      2f016ec8-7ab4-42f6-9a4b-0b17b231d3ac_wxs_gdc_r...
# 3      5408aaba-d172-525f-9c8d-22c9b6b88eef_wxs_gdc_r...
# 4      47ac282c-9780-5606-8173-688dda823a1b_wxs_gdc_r...
# ...                                                  ...
# 10675  ef5ac7e5-ca44-592c-96ec-4640c6c916bc_wxs_gdc_r...
# 10676  ef5ac7e5-ca44-592c-96ec-4640c6c916bc_wxs_gdc_r...
# 10677  ef5ac7e5-ca44-592c-96ec-4640c6c916bc_wxs_gdc_r...
# 10678  ef5ac7e5-ca44-592c-96ec-4640c6c916bc_wxs_gdc_r...
# 10679  97b8ca07-c131-496a-8987-19cd57d739e0_wxs_gdc_r...
#
#       experimental_strategy      data_type     data_category  \
# 0                       WXS  Aligned Reads  Sequencing Reads
# 1                       WXS  Aligned Reads  Sequencing Reads
# 2                       WXS  Aligned Reads  Sequencing Reads
# 3                       WXS  Aligned Reads  Sequencing Reads
# 4                       WXS  Aligned Reads  Sequencing Reads
# ...                     ...            ...               ...
# 10675                   WXS  Aligned Reads  Sequencing Reads
# 10676                   WXS  Aligned Reads  Sequencing Reads
# 10677                   WXS  Aligned Reads  Sequencing Reads
# 10678                   WXS  Aligned Reads  Sequencing Reads
# 10679                   WXS  Aligned Reads  Sequencing Reads
#
#                 case_id             sample_id                sample_type  \
# 0      TARGET-40-NAAGJT  TARGET-40-NAAGJT-10B       Blood Derived Normal
# 1      TARGET-40-NAAGJT  TARGET-40-NAAGJT-10B       Blood Derived Normal
# 2      TARGET-40-0A4I8O  TARGET-40-0A4I8O-10A       Blood Derived Normal
# 3      TARGET-40-PANPUM  TARGET-40-PANPUM-10A       Blood Derived Normal
# 4      TARGET-40-NAAEDH  TARGET-40-NAAEDH-08A  Post neo-adjuvant therapy
# ...                 ...                   ...                        ...
# 10675  TARGET-40-PAUTYB  TARGET-40-PAUTYB-01A              Primary Tumor
# 10676  TARGET-40-PAUTYB  TARGET-40-PAUTYB-01A              Primary Tumor
# 10677  TARGET-40-PAUTYB  TARGET-40-PAUTYB-01A              Primary Tumor
# 10678  TARGET-40-PAUTYB  TARGET-40-PAUTYB-01A              Primary Tumor
# 10679  TARGET-40-0A4HXO  TARGET-40-0A4HXO-10A       Blood Derived Normal
#
#                      aliquot_id                      workflow_type  \
# 0      TARGET-40-NAAGJT-10B-01D  BWA with Mark Duplicates and BQSR
# 1      TARGET-40-NAAGJT-10B-01D  BWA with Mark Duplicates and BQSR
# 2      TARGET-40-0A4I8O-10A-01D  BWA with Mark Duplicates and BQSR
# 3      TARGET-40-PANPUM-10A-01D  BWA with Mark Duplicates and BQSR
# 4      TARGET-40-NAAEDH-08A-01D  BWA with Mark Duplicates and BQSR
# ...                         ...                                ...
# 10675  TARGET-40-PAUTYB-01A-01D  BWA with Mark Duplicates and BQSR
# 10676  TARGET-40-PAUTYB-01A-01D  BWA with Mark Duplicates and BQSR
# 10677  TARGET-40-PAUTYB-01A-01D  BWA with Mark Duplicates and BQSR
# 10678  TARGET-40-PAUTYB-01A-01D  BWA with Mark Duplicates and BQSR
# 10679  TARGET-40-0A4HXO-10A-01D  BWA with Mark Duplicates and BQSR
#
#                               read_group_id target_capture_kit_name  \
# 0      5cee1f2f-3505-42a9-a2c8-f8feb0151d47                    None
# 1      d8a45ced-d16b-400c-ad58-1812f4a0ec41                    None
# 2      0da41968-16d3-4db3-b761-680c890bd6ee                    None
# 3      1f115a0d-7918-49fb-a97a-d8b88db3ce6f                    None
# 4      899646a7-d428-4616-a32e-c155fc7d1826                    None
# ...                                     ...                     ...
# 10675  05a19385-7d77-4429-83fe-42f2cae7f70f                    None
# 10676  6a63607a-1809-4813-a827-67ce954edf25                    None
# 10677  77cac466-ce20-499c-aa54-b61dda3301ee                    None
# 10678  8e741adf-1ee2-4943-be39-6fe450497a26                    None
# 10679  ff5ffa29-058a-4ff4-b77d-dc968f61f2a2                    None
#
#       target_capture_kit_target_region
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
# ...                                ...
# 10675                             None
# 10676                             None
# 10677                             None
# 10678                             None
# 10679                             None
#
# [10680 rows x 13 columns]

# %%
df.to_csv('./target-wxs.lib-info.csv', index=False, sep="\t")

# %%
import json
with open('data.json', 'w') as f:
    json.dump(gdc_response, f)

# %%
gdc_url = 'https://api.gdc.cancer.gov/files'
headers = {'Content-Type': 'application/json'}

fields = [
    'experimental_strategy',
    'cases.samples.portions.analytes.aliquots.submitter_id',
    'analysis.workflow_type'
]
fields = ','.join(fields)
payload = {
        'filters':{
            'op':'=',
            'content':{
                'field':'cases.samples.portions.analytes.aliquots.submitter_id',
                'value':[
                    'TARGET-30-PAPHPE-01A-01W',
                    'TARGET-40-0A4I42-01A-01D',
                    'TARGET-50-PAJMLZ-01A-01D',
                    'TARGET-50-PAEAFB-01A-01D',
                    'TARGET-50-PAJMIZ-01A-01D',
                    'TARGET-50-PAKULH-01A-02D',
                    'TARGET-40-PAUBIT-01A-01D',
                    'TARGET-40-PAUUML-01A-01D',
                    'TARGET-40-PAUVUL-01A-01D',
                    'TARGET-40-PAVALD-01A-01D',
                    'TARGET-40-PAUYTT-01A-01D',
                    'TARGET-40-PAVCLP-01A-01D',
                    'TARGET-10-PATXNR-09A-01D',
                    'TARGET-10-PATZYR-03A-01D',
                    'TARGET-10-PASMHF-09A-01D',
                    'TARGET-10-PASRMM-09A-01D',
                    'TARGET-10-PASSHC-09A-01D',
                    'TARGET-10-PASWSR-09A-01D',
                    'TARGET-10-PATEMI-09A-01D',
                    'TARGET-10-PATEYS-09A-01D',
                    'TARGET-10-PARPRW-04A-01D',
                    'TARGET-20-PAEEYP-04A-01D',
                    'TARGET-20-PAKKBK-04A-01D',
                    'TARGET-20-PASRTP-40A-01D',
                    'TARGET-40-PATKSS-01A-01D',
                    'TARGET-30-PAPHPE-10A-01W',
                    'TARGET-30-PAMMXF-10A-01W',
                    'TARGET-40-PAVECB-10A-01D',
                    'TARGET-50-PAKXXF-10A-01D',
                    'TARGET-50-PALDTE-10A-01D',
                    'TARGET-40-PAUBIT-10A-01Y',
                    'TARGET-40-PAUUML-10A-01D',
                    'TARGET-40-PAUVUL-10A-01D',
                    'TARGET-40-PAVALD-10A-01D',
                    'TARGET-40-PAUYTT-10A-01D',
                    'TARGET-40-PAUTWB-10A-01D',
                    'TARGET-40-PAUTYB-10A-01D',
                    'TARGET-40-PAUXPZ-10A-01D',
                    'TARGET-40-PAVCLP-10A-01D',
                    'TARGET-40-PAVDTY-10A-01D',
                    'TARGET-10-PASKAY-10A-01D',
                    'TARGET-10-PATRUN-10A-01D',
                    'TARGET-10-PAUBCB-10A-01D',
                    'TARGET-10-PAUBCT-10A-01D',
                    'TARGET-10-PASUSV-10A-01D',
                    'TARGET-10-PASWZJ-10A-01D',
                    'TARGET-10-PATEMI-10A-01D',
                    'TARGET-10-PATFWF-10A-01D',
                    'TARGET-40-PATKSS-10A-01D',
                    'TARGET-30-PAPTAN-14A-01D'

                ]
            }
        },
        'format':'json',
        'fields':fields,
        'size':5000 # make sure we get all the returns
}
payload = json.dumps(payload)
gdc_response = requests.post(gdc_url, headers=headers, data=payload)
gdc_response = gdc_response.json()
gdc_response
# lib_info = []
# for i in gdc_response['data']['hits']:
#     case = i['cases'][0]
#     sample = case['samples'][0]
#     aliquot = sample['portions'][0]['analytes'][0]['aliquots'][0]
#     try:
#         analysis = i['analysis']
#     except:
#         analysis = {
#             'workflow_type':'null',
#             'metadata':{
#                 'read_groups':[{
#                     'target_capture_kit_name':'null',
#                     'target_capture_kit_target_region':'null',
#                     'read_group_id':'null'
#                 }]
#             }
#         }
#     read_groups = analysis['metadata']['read_groups']
#     for j in read_groups:
#         lib_info.append([
#             i['file_id'], i['file_name'], i['experimental_strategy'],
#             i['data_type'], i['data_category'],
#             case['submitter_id'],
#             sample['submitter_id'], sample['sample_type'],
#             aliquot['submitter_id'],
#             analysis['workflow_type'],
#             j['read_group_id'],
#             j['target_capture_kit_name'],
#             j['target_capture_kit_target_region']
#         ])
# df = pd.DataFrame(lib_info).drop_duplicates()
# df.columns = [
#     'file_id',
#     'file_name',
#     'experimental_strategy',
#     'data_type',
#     'data_category',
#     'case_id',
#     'sample_id',
#     'sample_type',
#     'aliquot_id',
#     'workflow_type',
#     'read_group_id',
#     'target_capture_kit_name',
#     'target_capture_kit_target_region'
# ]
# df
# Out:
# {'data': {'hits': [{'id': '8f6a3259-9181-42ad-8561-f9b0b17b108e',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUYTT-01A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUYTT-10A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '3e7c17a1-af6f-4011-88d1-17b1f3b73cb7',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUYTT-01A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUYTT-10A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': 'ba3fb3c7-4beb-4d19-8a32-71084a8b222f',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-

#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PATZYR-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PATZYR-03A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '4387585c-7a19-419f-81b6-e3d6bc9e20cf',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAVDTY-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAVDTY-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': 'a50269d9-6d50-448f-931d-fe775a47c544',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-20-PAKKBK-14A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-20-PAKKBK-04A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': 'c5875730-4f37-414e-b0db-42a8e0386cff',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PAUBCB-09A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PAUBCB-10A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': 'dabd7548-76d4-4bc8-b772-461c958e2973',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PATXNR-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PATXNR-09A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '29e2f1d2-9fb6-43d3-8e38-3e589d7d8267',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PAUBCT-09A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PAUBCT-10A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': 'e09f742c-6570-419d-8bc6-3a743ff8f2e5',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-20-PAKKBK-14A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-20-PAKKBK-04A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '2fb12ba9-1bce-414b-ae0f-80bc94f732e4',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PATXNR-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PATXNR-09A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': 'af2dd169-cd60-40b5-98eb-10ad7f5074d1',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PATKSS-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PATKSS-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '7ec70d46-1980-41cf-9960-80cb75242814',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUBIT-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUBIT-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '26e6e487-87ca-4c05-b8fe-696462aef84d',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAVECB-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAVECB-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': 'e4d2c048-7ebe-46ff-ae9c-7c5a99ab01fe',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUVUL-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUVUL-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '5615f826-158e-417a-9bb1-0da300f481a1',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PATRUN-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PATRUN-09A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': 'af1c5159-f24c-4808-967a-a2253bda78ed',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PASUSV-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PASUSV-09A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '197cb45c-c616-47a4-bdda-2dcca77e3c0c',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUTWB-01A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUTWB-10A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': 'b8234136-fa00-4ec6-a23a-2c44a6562857',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUVUL-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUVUL-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '51407b16-3ed9-4681-b938-d45d75a296b6',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-0A4I42-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'BWA with Mark Duplicates and BQSR'},
#     'experimental_strategy': 'WGS'},
#    {'id': '63815649-b950-43ee-b2e4-cfc840651962',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAVDTY-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAVDTY-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '1917ee45-d7f8-44b9-841a-e85a407d953d',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAVCLP-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAVCLP-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '988b328c-9011-4d9e-b053-c9198d95767b',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-0A4I42-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-0A4I42-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '4e67c5b8-78b8-4256-8ff4-5209169a6b77',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUXPZ-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUXPZ-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '61900d5c-4c4b-4928-aed4-d7fcabf6b442',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PATEMI-09A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PATEMI-10A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': 'eabf409c-8b1f-4216-8d0f-9d0b42473cf0',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUTYB-01A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAUTYB-10A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '0061cb0b-ab0b-4323-98db-f92036bd4402',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PASUSV-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-10-PASUSV-09A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': 'f62eab42-761f-4990-83f2-a826d7db36da',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAVALD-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-PAVALD-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'},
#    {'id': '5b8844df-055e-4496-ba32-c747600365b4',
#     'cases': [{'samples': [{'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-0A4I42-10A-01D'}]}]}]},
#        {'portions': [{'analytes': [{'aliquots': [{'submitter_id': 'TARGET-40-0A4I42-01A-01D'}]}]}]}]}],
#     'analysis': {'workflow_type': 'ASCAT2'},
#     'experimental_strategy': 'Genotyping Array'}],
#   'pagination': {'count': 60,
#    'total': 60,
#    'size': 5000,
#    'from': 0,
#    'sort': '',
#    'page': 1,
#    'pages': 1}},
#  'warnings': {}}

# %%
json_formatted_str = json.dumps(gdc_response, indent=2)
print(json_formatted_str)
# Out:
# {
#   "data": {
#     "hits": [
#       {
#         "id": "8f6a3259-9181-42ad-8561-f9b0b17b108e",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PA
10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "0ecba392-b194-415a-ba8a-342054fbf6e4",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUBIT-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUBIT-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "e283554b-a8e5-4d49-9efc-8930f5e8ca8e",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUXPZ-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUXPZ-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "d30d5c57-c8f3-4f30-99ae-8e5968535b3f",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PATZYR-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PATZYR-03A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "4387585c-7a19-419f-81b6-e3d6bc9e20cf",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAVDTY-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAVDTY-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "a50269d9-6d50-448f-931d-fe775a47c544",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-20-PAKKBK-14A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-20-PAKKBK-04A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "c5875730-4f37-414e-b0db-42a8e0386cff",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PAUBCB-09A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PAUBCB-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "dabd7548-76d4-4bc8-b772-461c958e2973",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PATXNR-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PATXNR-09A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "29e2f1d2-9fb6-43d3-8e38-3e589d7d8267",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PAUBCT-09A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PAUBCT-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "e09f742c-6570-419d-8bc6-3a743ff8f2e5",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-20-PAKKBK-14A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-20-PAKKBK-04A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "2fb12ba9-1bce-414b-ae0f-80bc94f732e4",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PATXNR-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PATXNR-09A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "af2dd169-cd60-40b5-98eb-10ad7f5074d1",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PATKSS-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PATKSS-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "7ec70d46-1980-41cf-9960-80cb75242814",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUBIT-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUBIT-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "26e6e487-87ca-4c05-b8fe-696462aef84d",
# ...
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUVUL-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "5615f826-158e-417a-9bb1-0da300f481a1",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PATRUN-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PATRUN-09A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "af1c5159-f24c-4808-967a-a2253bda78ed",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PASUSV-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PASUSV-09A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "197cb45c-c616-47a4-bdda-2dcca77e3c0c",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUTWB-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUTWB-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "b8234136-fa00-4ec6-a23a-2c44a6562857",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUVUL-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUVUL-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "51407b16-3ed9-4681-b938-d45d75a296b6",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-0A4I42-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "BWA with Mark Duplicates and BQSR"
#         },
#         "experimental_strategy": "WGS"
#       },
#       {
#         "id": "63815649-b950-43ee-b2e4-cfc840651962",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAVDTY-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAVDTY-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "1917ee45-d7f8-44b9-841a-e85a407d953d",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAVCLP-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAVCLP-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "988b328c-9011-4d9e-b053-c9198d95767b",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-0A4I42-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-0A4I42-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "4e67c5b8-78b8-4256-8ff4-5209169a6b77",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUXPZ-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUXPZ-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "61900d5c-4c4b-4928-aed4-d7fcabf6b442",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PATEMI-09A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PATEMI-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "eabf409c-8b1f-4216-8d0f-9d0b42473cf0",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUTYB-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAUTYB-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "0061cb0b-ab0b-4323-98db-f92036bd4402",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PASUSV-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-10-PASUSV-09A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "f62eab42-761f-4990-83f2-a826d7db36da",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAVALD-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-PAVALD-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       },
#       {
#         "id": "5b8844df-055e-4496-ba32-c747600365b4",
#         "cases": [
#           {
#             "samples": [
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-0A4I42-10A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "portions": [
#                   {
#                     "analytes": [
#                       {
#                         "aliquots": [
#                           {
#                             "submitter_id": "TARGET-40-0A4I42-01A-01D"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "analysis": {
#           "workflow_type": "ASCAT2"
#         },
#         "experimental_strategy": "Genotyping Array"
#       }
#     ],
#     "pagination": {
#       "count": 60,
#       "total": 60,
#       "size": 5000,
#       "from": 0,
#       "sort": "",
#       "page": 1,
#       "pages": 1
#     }
#   },
#   "warnings": {}
# }
